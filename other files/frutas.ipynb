# %%
import pandas as pd

df_data = pd.read_excel("data/dados_frutas.xlsx")

df_data

from sklearn import tree

arvore = tree.DecisionTreeClassifier()

y = df_data["Fruta"]

caracteristicas = ["Arredondada","Suculenta","Vermelha","Doce"]
X = df_data[caracteristicas]

arvore.fit(X, y)

arvore.predict([[1,1,1,1]])

import matplotlib.pyplot as ptl

ptl.figure(dpi=300)
tree.plot_tree(arvore, 
               feature_names=caracteristicas, 
               class_names=arvore.classes_, 
               filled=True
               )
# Out:
# c:\Users\italo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# [Text(0.4444444444444444, 0.875, 'Vermelha <= 0.5\ngini = 0.857\nsamples = 7\nvalue = [1, 1, 1, 1, 1, 1, 1]\nclass = Banana'),
#  Text(0.2222222222222222, 0.625, 'Doce <= 0.5\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 1, 0, 0, 1, 0]\nclass = Banana'),
#  Text(0.3333333333333333, 0.75, 'True  '),
#  Text(0.1111111111111111, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Limão'),
#  Text(0.3333333333333333, 0.375, 'Suculenta <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 1, 0]\nclass = Banana'),
#  Text(0.2222222222222222, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Banana'),
#  Text(0.4444444444444444, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Pera'),
#  Text(0.6666666666666666, 0.625, 'Doce <= 0.5\ngini = 0.75\nsamples = 4\nvalue = [0, 1, 0, 1, 1, 0, 1]\nclass = Cereja'),
#  Text(0.5555555555555556, 0.75, '  False'),
#  Text(0.5555555555555556, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Tomate'),
#  Text(0.7777777777777778, 0.375, 'Arredondada <= 0.5\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 0, 1, 1, 0, 0]\nclass = Cereja'),
#  Text(0.6666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Morango'),
#  Text(0.8888888888888888, 0.125, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0, 0]\nclass = Cereja')]
